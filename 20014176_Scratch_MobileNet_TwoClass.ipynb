# %% [markdown]
# **Install Requirements**

# %%
# Student ID: 20014176

# MobileNet trained from scratch model on the HAM10000 dataset

# !pip install tensorflow==2.2.0
# !pip install keras

import tensorflow as tf
print(tf.__version__)
# Out:
# Collecting tensorflow==2.2.0
#   Downloading https://files.pythonhosted.org/packages/4c/1a/0d79814736cfecc825ab8094b39648cc9c46af7af1bae839928acb73b4dd/tensorflow-2.2.0-cp37-cp37m-manylinux2010_x86_64.whl (516.2MB)
#      |████████████████████████████████| 516.2MB 32kB/s
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0) (1.32.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0) (3.3.0)
# Requirement already satisfied: google-pasta>=0.1.8 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0) (0.2.0)
# Requirement already satisfied: protobuf>=3.8.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0) (3.12.4)
# Collecting tensorflow-estimator<2.3.0,>=2.2.0
#   Downloading https://files.pythonhosted.org/packages/a4/f5/926ae53d6a226ec0fda5208e0e581cffed895ccc89e36ba76a8e60895b78/tensorflow_estimator-2.2.0-py2.py3-none-any.whl (454kB)
#      |████████████████████████████████| 460kB 35.0MB/s
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0) (1.12.1)
# Requirement already satisfied: gast==0.3.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0) (0.3.3)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0) (0.36.2)
# Collecting tensorboard<2.3.0,>=2.2.0
#   Downloading https://files.pythonhosted.org/packages/1d/74/0a6fcb206dcc72a6da9a62dd81784bfdbff5fedb099982861dc2219014fb/tensorboard-2.2.2-py3-none-any.whl (3.0MB)
#      |████████████████████████████████| 3.0MB 46.3MB/s
# Requirement already satisfied: keras-preprocessing>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0) (1.1.2)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0) (1.19.5)
# Requirement already satisfied: astunparse==1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0) (1.6.3)
# Requirement already satisfied: six>=1.12.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0) (1.15.0)
# Requirement already satisfied: scipy==1.4.1; python_version >= "3" in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0) (1.4.1)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0) (1.1.0)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0) (0.12.0)
# Requirement already satisfied: h5py<2.11.0,>=2.10.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==2.2.0) (2.10.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from protobuf>=3.8.0->tensorflow==2.2.0) (56.1.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (3.3.4)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (1.8.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (0.4.4)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (2.23.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (1.28.1)
# Requirement already satisfied: importlib-metadata; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (3.10.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (1.3.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (2.10)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (4.7.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (4.2.1)
# Requirement already satisfied: typing-extensions>=3.6.4; python_version < "3.8" in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (3.7.4.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata; python_version < "3.8"->markdown>=2.6.8->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (3.4.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (3.1.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.7/dist-packages (from rsa<5,>=3.1.4; python_version >= "3.6"->google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2.0) (0.4.8)
# Installing collected packages: tensorflow-estimator, tensorboard, tensorflow
#   Found existing installation: tensorflow-estimator 2.4.0
#     Uninstalling tensorflow-estimator-2.4.0:
#       Successfully uninstalled tensorflow-estimator-2.4.0
#   Found existing installation: tensorboard 2.4.1
#     Uninstalling tensorboard-2.4.1:
#       Successfully uninstalled tensorboard-2.4.1
#   Found existing installation: tensorflow 2.4.1
#     Uninstalling tensorflow-2.4.1:
#       Successfully uninstalled tensorflow-2.4.1
# Successfully installed tensorboard-2.2.2 tensorflow-2.2.0 tensorflow-estimator-2.2.0
# Requirement already satisfied: keras in /usr/local/lib/python3.7/dist-packages (2.4.3)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras) (2.10.0)
# Requirement already satisfied: numpy>=1.9.1 in /usr/local/lib/python3.7/dist-packages (from keras) (1.19.5)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.7/dist-packages (from keras) (3.13)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/dist-packages (from keras) (1.4.1)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from h5py->keras) (1.15.0)
# 2.2.0

# %% [markdown]
# **Read Dataset**

# %%
# zipped dataset is uploaded to google drive to be accessed by Google Colab

from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# unzip dataset

# !unzip "drive/MyDrive/UNUK Year 3 Dissertation/Dataset/Dataset.zip" -d "drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029326.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029327.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029328.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029329.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029330.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029331.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029332.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029333.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029334.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029335.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029336.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029337.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029338.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029339.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029340.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029341.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029342.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029343.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029344.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029345.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029346.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029347.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029348.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029349.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029350.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029351.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029352.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029353.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029354.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029355.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029356.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029357.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029358.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029359.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029360.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029361.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029362.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029363.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029364.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029365.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029366.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029367.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029368.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029369.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029370.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029371.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029372.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029373.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029374.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029375.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029376.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029377.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029378.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029379.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029380.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029381.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029382.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029383.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029384.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029385.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029386.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029387.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029388.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029389.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029390.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029391.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029392.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029393.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029394.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029395.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029396.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029397.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029398.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029399.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029400.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029401.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029402.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029403.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029404.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029405.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029406.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029407.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029408.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029409.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029410.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029411.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029412.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029413.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029414.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029415.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029416.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029417.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029418.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029419.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029420.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029421.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029422.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029423.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029424.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029425.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029426.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029427.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029428.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029429.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029430.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029431.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029432.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029433.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029434.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029435.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029436.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029437.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029438.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029439.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029440.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029441.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029442.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029443.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029444.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029445.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029446.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029447.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029448.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029449.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029450.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029451.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029452.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029453.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029454.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029455.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029456.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029457.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029458.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029459.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029460.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029461.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029462.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029463.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029464.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029465.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029466.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029467.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029468.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029469.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029470.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029471.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029472.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029473.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029474.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029475.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029476.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029477.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029478.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029479.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029480.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029481.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029482.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029483.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029484.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029485.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029486.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029487.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029488.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029489.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029490.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029491.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029492.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029493.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029494.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029495.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029496.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029497.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029498.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029499.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029500.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029501.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029502.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029503.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029504.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029505.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029506.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029507.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029508.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029509.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029510.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029511.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029512.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029513.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029514.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029515.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029516.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029517.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029518.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029519.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029520.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029521.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029522.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029523.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029524.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029525.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029526.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029527.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029528.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029529.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029530.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029531.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029532.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029533.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029534.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029535.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029536.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029537.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029538.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029539.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029540.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029541.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029542.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029543.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029544.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029545.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029546.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029547.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029548.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029549.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029550.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029551.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029552.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029553.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029554.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029555.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029556.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029557.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029558.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029559.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029560.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029561.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029562.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029563.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029564.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029565.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029566.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029567.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029568.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029569.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029570.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029571.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029572.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029573.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029574.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029575.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029576.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029577.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029578.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029579.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029580.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029581.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029582.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029583.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029584.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029585.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029586.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029587.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029588.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029589.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029590.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029591.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029592.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029593.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029594.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029595.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029596.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029597.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029598.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029599.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029600.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029601.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029602.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029603.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029604.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029605.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029606.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029607.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029608.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029609.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029610.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029611.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029612.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029613.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029614.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029615.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029616.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029617.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029618.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029619.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029620.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029621.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029622.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029623.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029624.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029625.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029626.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029627.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029628.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029629.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029630.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029631.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029632.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029633.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029634.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029635.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029636.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029637.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029638.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029639.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029640.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029641.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029642.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029643.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029644.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029645.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029646.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029647.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029648.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029649.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029650.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029651.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029652.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029653.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029654.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029655.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029656.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029657.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029658.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029659.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029660.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029661.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029662.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029663.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029664.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029665.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029666.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029667.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029668.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029669.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029670.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029671.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029672.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029673.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029674.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029675.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029676.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029677.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029678.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029679.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029680.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029681.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029682.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029683.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029684.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029685.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029686.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029687.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029688.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029689.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029690.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029691.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029692.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029693.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029694.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029695.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029696.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029697.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029698.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029699.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029700.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029701.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029702.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029703.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029704.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0029705.jpg
# ...
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034199.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034200.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034201.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034202.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034203.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034204.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034205.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034206.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034207.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034208.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034209.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034210.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034211.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034212.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034213.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034214.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034215.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034216.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034217.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034218.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034219.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034220.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034221.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034222.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034223.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034224.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034225.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034226.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034227.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034228.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034229.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034230.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034231.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034232.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034233.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034234.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034235.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034236.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034237.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034238.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034239.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034240.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034241.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034242.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034243.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034244.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034245.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034246.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034247.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034248.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034249.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034250.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034251.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034252.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034253.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034254.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034255.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034256.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034257.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034258.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034259.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034260.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034261.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034262.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034263.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034264.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034265.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034266.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034267.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034268.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034269.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034270.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034271.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034272.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034273.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034274.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034275.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034276.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034277.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034278.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034279.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034280.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034281.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034282.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034283.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034284.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034285.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034286.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034287.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034288.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034289.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034290.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034291.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034292.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034293.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034294.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034295.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034296.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034297.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034298.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034299.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034300.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034301.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034302.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034303.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034304.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034305.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034306.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034307.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034308.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034309.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034310.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034311.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034312.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034313.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034314.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034315.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034316.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034317.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034318.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034319.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0034320.jpg
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_metadata.csv
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/hmnist_28_28_L.csv
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/hmnist_28_28_RGB.csv
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/hmnist_8_8_L.csv
#   inflating: drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/hmnist_8_8_RGB.csv

# %% [markdown]
# **Load Imports**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
import tensorflow as tf
import keras
from sklearn.metrics import confusion_matrix, classification_report
from keras.optimizers import Adam
from keras.applications import MobileNet
import cv2
import os

# %% [markdown]
# **Read images in dataset**

# %%
# read all files in dataset folder

for dirname, _, filenames in os.walk('drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
        img = cv2.imread(os.path.join(dirname, filename))
        if img is not None:
            print(img.shape)
            break
# Out:
# drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_metadata.csv
# drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/hmnist_8_8_L.csv
# drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/hmnist_8_8_RGB.csv
# drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/hmnist_28_28_L.csv
# drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/hmnist_28_28_RGB.csv
# drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_2/ISIC_0033635.jpg
# (450, 600, 3)
# drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_images_part_1/ISIC_0028619.jpg
# (450, 600, 3)

# %% [markdown]
# **More Imports**

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import cv2
import os
import numpy as np
import pandas as pd
import os
from glob import glob
import seaborn as sns
from PIL import Image
np.random.seed(123)
from sklearn.preprocessing import label_binarize
from sklearn.metrics import confusion_matrix,classification_report
import itertools
import keras
from keras.utils.np_utils import to_categorical # used for converting labels to one-hot-encoding
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten, Conv2D, MaxPool2D
from keras import backend as K
import itertools
from keras.layers.normalization import BatchNormalization
from keras.utils.np_utils import to_categorical # convert to one-hot-encoding
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator
from keras.callbacks import ReduceLROnPlateau
from sklearn.model_selection import train_test_split

# %% [markdown]
# **Merge Images from Both Folders into One Dictionary**

# %%
base_skin_dir = os.path.join('drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset')

imageid_path_dict = {os.path.splitext(os.path.basename(x))[0]: x
                     for x in glob(os.path.join(base_skin_dir, '*', '*.jpg'))}

# label mapping for benign and malignant images

lesion_type_dict = {
    'b': 'benign',
    'm': 'malignant'
}

# %% [markdown]
# **Read from CSV File**

# %%
skin_df = pd.read_csv("drive/MyDrive/UNUK Year 3 Dissertation/Dataset/UnzippedDataset/Dataset/HAM10000_metadata.csv")

# %% [markdown]
# **change labels for 'dx'**

# %%
# dx is modified to "b" = benign and "m" = malignant

skin_df.loc[skin_df.dx == 'nv', 'dx'] = 'b'
skin_df.loc[skin_df.dx == 'mel', 'dx'] = 'm'
skin_df.loc[skin_df.dx == 'bkl', 'dx'] = 'b'
skin_df.loc[skin_df.dx == 'bcc', 'dx'] = 'm'
skin_df.loc[skin_df.dx == 'akiec', 'dx'] = 'b'
skin_df.loc[skin_df.dx == 'vasc', 'dx'] = 'b'
skin_df.loc[skin_df.dx == 'df', 'dx'] = 'b'

# %% [markdown]
# **Create New Columns in CSV**

# %%
# new columns are added to skin_df for better labels

skin_df['path'] = skin_df['image_id'].map(imageid_path_dict.get)
skin_df['cell_type'] = skin_df['dx'].map(lesion_type_dict.get) 
skin_df['cell_type_idx'] = pd.Categorical(skin_df['cell_type']).codes

# %% [markdown]
# **Display Contents of CSV File**

# %%
skin_df.head()
# Out:
#      lesion_id      image_id  ... cell_type cell_type_idx
# 0  HAM_0000118  ISIC_0027419  ...    benign             0
# 1  HAM_0000118  ISIC_0025030  ...    benign             0
# 2  HAM_0002730  ISIC_0026769  ...    benign             0
# 3  HAM_0002730  ISIC_0025661  ...    benign             0
# 4  HAM_0001466  ISIC_0031633  ...    benign             0
#
# [5 rows x 10 columns]

# %%
# run this to ensure that both benign and malignant are labelled correctly in the dataset

skin_df
# Out:
#          lesion_id      image_id  ...  cell_type cell_type_idx
# 0      HAM_0000118  ISIC_0027419  ...     benign             0
# 1      HAM_0000118  ISIC_0025030  ...     benign             0
# 2      HAM_0002730  ISIC_0026769  ...     benign             0
# 3      HAM_0002730  ISIC_0025661  ...     benign             0
# 4      HAM_0001466  ISIC_0031633  ...     benign             0
# ...            ...           ...  ...        ...           ...
# 10010  HAM_0002867  ISIC_0033084  ...     benign             0
# 10011  HAM_0002867  ISIC_0033550  ...     benign             0
# 10012  HAM_0002867  ISIC_0033536  ...     benign             0
# 10013  HAM_0000239  ISIC_0032854  ...     benign             0
# 10014  HAM_0003521  ISIC_0032258  ...  malignant             1
#
# [10015 rows x 10 columns]

# %% [markdown]
# **See Number of Images for Each Label**

# %%
skin_df['dx'].value_counts().plot.bar(rot=0)
plt.title('Number of images for different dx type')
plt.xlabel('dx')
plt.ylabel('Counts')
plt.grid(axis='y')

# %% [markdown]
# **Display Skin Lesion Types Count**

# %%
fig, ax1 = plt.subplots(1, 1, figsize= (10, 5))
skin_df['cell_type'].value_counts().plot(kind='bar', ax=ax1)

# %% [markdown]
# **Display Localization of Lesions**

# %%
skin_df['localization'].value_counts().plot(kind='bar')

# %% [markdown]
# **Resize Shape of Images**

# %%
# our CNN accepts inputs of size 150 x 100
# reshape all images in the dataset to standardize

skin_df['image'] = skin_df['path'].map(lambda x: np.asarray(Image.open(x).resize((150,100))))

# %% [markdown]
# **Check Shape of Images**

# %%
# ensure that all image sizes are correct

skin_df['image'].map(lambda x: x.shape).value_counts()
# Out:
# (100, 150, 3)    10015
# Name: image, dtype: int64

# %% [markdown]
# **Assign Features and Targets**

# %%
features = skin_df.drop(columns = ['cell_type_idx'], axis=1)
target = skin_df['cell_type_idx']

# %% [markdown]
# **Train Test Split 1**

# %%
x_train_o, x_test_o, y_train_o, y_test_o = train_test_split(features, target, test_size=0.20)

# %%
x_train = np.asarray(x_train_o['image'].tolist())
x_test = np.asarray(x_test_o['image'].tolist())

x_train_mean = np.mean(x_train)
x_train_std = np.std(x_train)

x_test_mean = np.mean(x_test)
x_test_std = np.std(x_test)

x_train = (x_train - x_train_mean)/x_train_std
x_test = (x_test - x_test_mean)/x_test_std

# %% [markdown]
# **Assign Number of Classes**

# %%
y_train = to_categorical(y_train_o, num_classes = 2)
y_test = to_categorical(y_test_o, num_classes = 2)

# %% [markdown]
# **Train Test Split 2**

# %%
x_train, x_validate, y_train, y_validate = train_test_split(x_train, y_train, test_size = 0.1)

# %% [markdown]
# **Reshape for Input**

# %%
# all 3 sets need to be the same size

x_train = x_train.reshape(x_train.shape[0], *(100, 150, 3))
x_test = x_test.reshape(x_test.shape[0], *(100, 150, 3))
x_validate = x_validate.reshape(x_validate.shape[0], *(100, 150, 3))

# %% [markdown]
# **Assign Input Shape and No of Classes for MobileNet**

# %%
input_shape = (100, 150, 3)
num_classes = 2

# %% [markdown]
# **Load MobileNet architecture**

# %%
base_model = MobileNet(weights = None, include_top = False , input_shape = (100, 150, 3))

# %% [markdown]
# **Configure Layers in MobileNet**

# %%
from keras.models import Sequential , Model
from keras.layers import Dropout , GlobalAveragePooling2D

x = base_model.output
x = Dropout(0.5)(x)
x = GlobalAveragePooling2D()(x)
x = Dense(128, activation='relu')(x)
x = BatchNormalization()(x)

predictions = Dense(2, activation = 'sigmoid')(x)

model = Model(inputs = base_model.input, outputs = predictions)

# %% [markdown]
# **Display Model Summary**

# %%
# see model summary

model.summary()
tf.keras.utils.plot_model(model)
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 100, 150, 3)]     0
# _________________________________________________________________
# conv1_pad (ZeroPadding2D)    (None, 101, 151, 3)       0
# _________________________________________________________________
# conv1 (Conv2D)               (None, 50, 75, 32)        864
# _________________________________________________________________
# conv1_bn (BatchNormalization (None, 50, 75, 32)        128
# _________________________________________________________________
# conv1_relu (ReLU)            (None, 50, 75, 32)        0
# _________________________________________________________________
# conv_dw_1 (DepthwiseConv2D)  (None, 50, 75, 32)        288
# _________________________________________________________________
# conv_dw_1_bn (BatchNormaliza (None, 50, 75, 32)        128
# _________________________________________________________________
# conv_dw_1_relu (ReLU)        (None, 50, 75, 32)        0
# _________________________________________________________________
# conv_pw_1 (Conv2D)           (None, 50, 75, 64)        2048
# _________________________________________________________________
# conv_pw_1_bn (BatchNormaliza (None, 50, 75, 64)        256
# _________________________________________________________________
# conv_pw_1_relu (ReLU)        (None, 50, 75, 64)        0
# _________________________________________________________________
# conv_pad_2 (ZeroPadding2D)   (None, 51, 76, 64)        0
# _________________________________________________________________
# conv_dw_2 (DepthwiseConv2D)  (None, 25, 37, 64)        576
# _________________________________________________________________
# conv_dw_2_bn (BatchNormaliza (None, 25, 37, 64)        256
# _________________________________________________________________
# conv_dw_2_relu (ReLU)        (None, 25, 37, 64)        0
# _________________________________________________________________
# conv_pw_2 (Conv2D)           (None, 25, 37, 128)       8192
# _________________________________________________________________
# conv_pw_2_bn (BatchNormaliza (None, 25, 37, 128)       512
# _________________________________________________________________
# conv_pw_2_relu (ReLU)        (None, 25, 37, 128)       0
# _________________________________________________________________
# conv_dw_3 (DepthwiseConv2D)  (None, 25, 37, 128)       1152
# _________________________________________________________________
# conv_dw_3_bn (BatchNormaliza (None, 25, 37, 128)       512
# _________________________________________________________________
# conv_dw_3_relu (ReLU)        (None, 25, 37, 128)       0
# _________________________________________________________________
# conv_pw_3 (Conv2D)           (None, 25, 37, 128)       16384
# _________________________________________________________________
# conv_pw_3_bn (BatchNormaliza (None, 25, 37, 128)       512
# _________________________________________________________________
# conv_pw_3_relu (ReLU)        (None, 25, 37, 128)       0
# _________________________________________________________________
# conv_pad_4 (ZeroPadding2D)   (None, 26, 38, 128)       0
# _________________________________________________________________
# conv_dw_4 (DepthwiseConv2D)  (None, 12, 18, 128)       1152
# _________________________________________________________________
# conv_dw_4_bn (BatchNormaliza (None, 12, 18, 128)       512
# _________________________________________________________________
# conv_dw_4_relu (ReLU)        (None, 12, 18, 128)       0
# _________________________________________________________________
# conv_pw_4 (Conv2D)           (None, 12, 18, 256)       32768
# _________________________________________________________________
# conv_pw_4_bn (BatchNormaliza (None, 12, 18, 256)       1024
# _________________________________________________________________
# conv_pw_4_relu (ReLU)        (None, 12, 18, 256)       0
# _________________________________________________________________
# conv_dw_5 (DepthwiseConv2D)  (None, 12, 18, 256)       2304
# _________________________________________________________________
# conv_dw_5_bn (BatchNormaliza (None, 12, 18, 256)       1024
# _________________________________________________________________
# conv_dw_5_relu (ReLU)        (None, 12, 18, 256)       0
# _________________________________________________________________
# conv_pw_5 (Conv2D)           (None, 12, 18, 256)       65536
# _________________________________________________________________
# conv_pw_5_bn (BatchNormaliza (None, 12, 18, 256)       1024
# _________________________________________________________________
# conv_pw_5_relu (ReLU)        (None, 12, 18, 256)       0
# _________________________________________________________________
# conv_pad_6 (ZeroPadding2D)   (None, 13, 19, 256)       0
# _________________________________________________________________
# conv_dw_6 (DepthwiseConv2D)  (None, 6, 9, 256)         2304
# _________________________________________________________________
# conv_dw_6_bn (BatchNormaliza (None, 6, 9, 256)         1024
# _________________________________________________________________
# conv_dw_6_relu (ReLU)        (None, 6, 9, 256)         0
# _________________________________________________________________
# conv_pw_6 (Conv2D)           (None, 6, 9, 512)         131072
# _________________________________________________________________
# conv_pw_6_bn (BatchNormaliza (None, 6, 9, 512)         2048
# _________________________________________________________________
# conv_pw_6_relu (ReLU)        (None, 6, 9, 512)         0
# _________________________________________________________________
# conv_dw_7 (DepthwiseConv2D)  (None, 6, 9, 512)         4608
# _________________________________________________________________
# conv_dw_7_bn (BatchNormaliza (None, 6, 9, 512)         2048
# _________________________________________________________________
# conv_dw_7_relu (ReLU)        (None, 6, 9, 512)         0
# _________________________________________________________________
# conv_pw_7 (Conv2D)           (None, 6, 9, 512)         262144
# _________________________________________________________________
# conv_pw_7_bn (BatchNormaliza (None, 6, 9, 512)         2048
# _________________________________________________________________
# conv_pw_7_relu (ReLU)        (None, 6, 9, 512)         0
# _________________________________________________________________
# conv_dw_8 (DepthwiseConv2D)  (None, 6, 9, 512)         4608
# _________________________________________________________________
# conv_dw_8_bn (BatchNormaliza (None, 6, 9, 512)         2048
# _________________________________________________________________
# conv_dw_8_relu (ReLU)        (None, 6, 9, 512)         0
# _________________________________________________________________
# conv_pw_8 (Conv2D)           (None, 6, 9, 512)         262144
# _________________________________________________________________
# conv_pw_8_bn (BatchNormaliza (None, 6, 9, 512)         2048
# _________________________________________________________________
# conv_pw_8_relu (ReLU)        (None, 6, 9, 512)         0
# _________________________________________________________________
# conv_dw_9 (DepthwiseConv2D)  (None, 6, 9, 512)         4608
# _________________________________________________________________
# conv_dw_9_bn (BatchNormaliza (None, 6, 9, 512)         2048
# _________________________________________________________________
# conv_dw_9_relu (ReLU)        (None, 6, 9, 512)         0
# _________________________________________________________________
# conv_pw_9 (Conv2D)           (None, 6, 9, 512)         262144
# _________________________________________________________________
# conv_pw_9_bn (BatchNormaliza (None, 6, 9, 512)         2048
# _________________________________________________________________
# conv_pw_9_relu (ReLU)        (None, 6, 9, 512)         0
# _________________________________________________________________
# conv_dw_10 (DepthwiseConv2D) (None, 6, 9, 512)         4608
# _________________________________________________________________
# conv_dw_10_bn (BatchNormaliz (None, 6, 9, 512)         2048
# _________________________________________________________________
# conv_dw_10_relu (ReLU)       (None, 6, 9, 512)         0
# _________________________________________________________________
# conv_pw_10 (Conv2D)          (None, 6, 9, 512)         262144
# _________________________________________________________________
# conv_pw_10_bn (BatchNormaliz (None, 6, 9, 512)         2048
# _________________________________________________________________
# conv_pw_10_relu (ReLU)       (None, 6, 9, 512)         0
# _________________________________________________________________
# conv_dw_11 (DepthwiseConv2D) (None, 6, 9, 512)         4608
# _________________________________________________________________
# conv_dw_11_bn (BatchNormaliz (None, 6, 9, 512)         2048
# _________________________________________________________________
# conv_dw_11_relu (ReLU)       (None, 6, 9, 512)         0
# _________________________________________________________________
# conv_pw_11 (Conv2D)          (None, 6, 9, 512)         262144
# _________________________________________________________________
# conv_pw_11_bn (BatchNormaliz (None, 6, 9, 512)         2048
# _________________________________________________________________
# conv_pw_11_relu (ReLU)       (None, 6, 9, 512)         0
# _________________________________________________________________
# conv_pad_12 (ZeroPadding2D)  (None, 7, 10, 512)        0
# _________________________________________________________________
# conv_dw_12 (DepthwiseConv2D) (None, 3, 4, 512)         4608
# _________________________________________________________________
# conv_dw_12_bn (BatchNormaliz (None, 3, 4, 512)         2048
# _________________________________________________________________
# conv_dw_12_relu (ReLU)       (None, 3, 4, 512)         0
# _________________________________________________________________
# conv_pw_12 (Conv2D)          (None, 3, 4, 1024)        524288
# _________________________________________________________________
# conv_pw_12_bn (BatchNormaliz (None, 3, 4, 1024)        4096
# _________________________________________________________________
# conv_pw_12_relu (ReLU)       (None, 3, 4, 1024)        0
# _________________________________________________________________
# conv_dw_13 (DepthwiseConv2D) (None, 3, 4, 1024)        9216
# _________________________________________________________________
# conv_dw_13_bn (BatchNormaliz (None, 3, 4, 1024)        4096
# _________________________________________________________________
# conv_dw_13_relu (ReLU)       (None, 3, 4, 1024)        0
# _________________________________________________________________
# conv_pw_13 (Conv2D)          (None, 3, 4, 1024)        1048576
# _________________________________________________________________
# conv_pw_13_bn (BatchNormaliz (None, 3, 4, 1024)        4096
# _________________________________________________________________
# conv_pw_13_relu (ReLU)       (None, 3, 4, 1024)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 3, 4, 1024)        0
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 1024)              0
# _________________________________________________________________
# dense (Dense)                (None, 128)               131200
# _________________________________________________________________
# batch_normalization (BatchNo (None, 128)               512
# _________________________________________________________________
# dense_1 (Dense)              (None, 2)                 258
# =================================================================
# Total params: 3,360,834
# Trainable params: 3,338,690
# Non-trainable params: 22,144
# _________________________________________________________________

# %% [markdown]
# **Load Adam Optimizer**

# %%
optimizer = Adam(lr = 0.001, beta_1 = 0.9, beta_2 = 0.999, epsilon = None, decay = 0.0, amsgrad = False)

# %% [markdown]
# **Compile Model**

# %%
model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

# %% [markdown]
# **Learning Rate Reduction**

# %%
learning_rate_reduction = ReduceLROnPlateau(monitor = 'val_accuracy', 
                                            patience = 3, 
                                            verbose = 1, 
                                            factor = 0.5, 
                                            min_lr = 0.00001)

# %% [markdown]
# **Image Data Generator**

# %%
from keras.preprocessing.image import ImageDataGenerator

datagen = ImageDataGenerator(
        featurewise_center = False,  
        samplewise_center = False, 
        featurewise_std_normalization = False, 
        samplewise_std_normalization = False, 
        zca_whitening = False,  
        rotation_range = 10, 
        zoom_range = 0.1,  
        width_shift_range = 0.1,  
        height_shift_range = 0.1,
        horizontal_flip = False,
        vertical_flip = False)

datagen.fit(x_train)

# %% [markdown]
# **Model Training and Testing**

# %%
epochs = 10
batch_size = 32


history = model.fit(datagen.flow(x_train,y_train, batch_size = batch_size),
    steps_per_epoch=x_train.shape[0] // batch_size,
    epochs=epochs,
    validation_data=(x_validate,y_validate),
    validation_steps=x_validate.shape[0] // batch_size
    ,callbacks=[learning_rate_reduction])
# Out:
# Epoch 1/10
# 225/225 [==============================] - 503s 2s/step - loss: 0.4120 - accuracy: 0.7724 - val_loss: 0.5327 - val_accuracy: 0.8229 - lr: 0.0010
# Epoch 2/10
# 225/225 [==============================] - 500s 2s/step - loss: 0.3750 - accuracy: 0.8065 - val_loss: 0.5153 - val_accuracy: 0.8229 - lr: 0.0010
# Epoch 3/10
# 225/225 [==============================] - 484s 2s/step - loss: 0.3615 - accuracy: 0.8231 - val_loss: 0.6316 - val_accuracy: 0.8229 - lr: 0.0010
# Epoch 4/10
# 225/225 [==============================] - ETA: 0s - loss: 0.3575 - accuracy: 0.8275
# Epoch 00004: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
# 225/225 [==============================] - 485s 2s/step - loss: 0.3575 - accuracy: 0.8275 - val_loss: 0.3852 - val_accuracy: 0.7768 - lr: 0.0010
# Epoch 5/10
# 225/225 [==============================] - 479s 2s/step - loss: 0.3509 - accuracy: 0.8270 - val_loss: 0.3862 - val_accuracy: 0.7905 - lr: 5.0000e-04
# Epoch 6/10
# 225/225 [==============================] - 483s 2s/step - loss: 0.3409 - accuracy: 0.8383 - val_loss: 0.3671 - val_accuracy: 0.8229 - lr: 5.0000e-04
# Epoch 7/10
#  16/225 [=>............................] - ETA: 6:44 - loss: 0.3308 - accuracy: 0.8418
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-358aaae683bc> in <module>()
#       8     validation_data=(x_validate,y_validate),
#       9     validation_steps=x_validate.shape[0] // batch_size
# ---> 10     ,callbacks=[learning_rate_reduction])
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py in _method_wrapper(self, *args, **kwargs)
#      64   def _method_wrapper(self, *args, **kwargs):
#      65     if not self._in_multi_worker_mode():  # pylint: disable=protected-access
# ---> 66       return method(self, *args, **kwargs)
#      67
#      68     # Running inside `run_distribute_coordinator` already.
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#     846                 batch_size=batch_size):
#     847               callbacks.on_train_batch_begin(step)
# --> 848               tmp_logs = train_function(iterator)
#     849               # Catch OutOfRangeError for Datasets of unknown size.
#     850               # This blocks until the batch has finished executing.
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in __call__(self, *args, **kwds)
#     578         xla_context.Exit()
#     579     else:
# --> 580       result = self._call(*args, **kwds)
#     581
#     582     if tracing_count == self._get_tracing_count():
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/def_function.py in _call(self, *args, **kwds)
#     609       # In this case we have created variables on the first call, so we run the
#     610       # defunned version which is guaranteed to never create variables.
# --> 611       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     612     elif self._stateful_fn is not None:
#     613       # Release the lock early so that multiple threads can perform the call
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in __call__(self, *args, **kwargs)
#    2418     with self._lock:
#    2419       graph_function, args, kwargs = self._maybe_define_function(args, kwargs)
# -> 2420     return graph_function._filtered_call(args, kwargs)  # pylint: disable=protected-access
#    2421
#    2422   @property
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _filtered_call(self, args, kwargs)
#    1663          if isinstance(t, (ops.Tensor,
#    1664                            resource_variable_ops.BaseResourceVariable))),
# -> 1665         self.captured_inputs)
#    1666
#    1667   def _call_flat(self, args, captured_inputs, cancellation_manager=None):
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1744       # No tape is watching; skip to running the function.
#    1745       return self._build_call_outputs(self._inference_function.call(
# -> 1746           ctx, args, cancellation_manager=cancellation_manager))
#    1747     forward_backward = self._select_forward_and_backward_functions(
#    1748         args,
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/function.py in call(self, ctx, args, cancellation_manager)
#     596               inputs=args,
#     597               attrs=attrs,
# --> 598               ctx=ctx)
#     599         else:
#     600           outputs = execute.execute_with_cancellation(
#
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/eager/execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      58     ctx.ensure_initialized()
#      59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
# ---> 60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#      62     if name is not None:
#
# KeyboardInterrupt:

# %% [markdown]
# **Plot Model's Validation Loss and Validation Accuracy**

# %%
def plot_model_history(model_history):
    fig, axs = plt.subplots(1,2,figsize=(15,5))

    # summarize history for accuracy
    axs[0].plot(range(1,len(model_history.history['acc'])+1),model_history.history['acc'])
    axs[0].plot(range(1,len(model_history.history['val_acc'])+1),model_history.history['val_acc'])
    axs[0].set_title('Model Accuracy')
    axs[0].set_ylabel('Accuracy')
    axs[0].set_xlabel('Epoch')
    axs[0].set_xticks(np.arange(1,len(model_history.history['acc'])+1),len(model_history.history['acc'])/10)
    axs[0].legend(['train', 'val'], loc='best')
    
    # summarize history for loss
    axs[1].plot(range(1,len(model_history.history['loss'])+1),model_history.history['loss'])
    axs[1].plot(range(1,len(model_history.history['val_loss'])+1),model_history.history['val_loss'])
    axs[1].set_title('Model Loss')
    axs[1].set_ylabel('Loss')
    axs[1].set_xlabel('Epoch')
    axs[1].set_xticks(np.arange(1,len(model_history.history['loss'])+1),len(model_history.history['loss'])/10)
    axs[1].legend(['train', 'val'], loc='best')
    plt.show()

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(acc) + 1)
plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'r', label='Validation acc')
plt.title('Training and validation accuracy')
plt.legend()
plt.figure()
plt.plot(epochs, loss, 'bo', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.legend()
plt.show()

# %% [markdown]
# **Display Validation and Test Accuracy**

# %%
loss, accuracy = model.evaluate(x_test, y_test, verbose=1)
loss_v, accuracy_v = model.evaluate(x_validate, y_validate, verbose=1)

print("Validation: accuracy = %f  ;  loss_v = %f" % (accuracy_v, loss_v))
print("Test: accuracy = %f  ;  loss = %f" % (accuracy, loss))
# Out:
# 63/63 [==============================] - 24s 382ms/step - loss: 0.3301 - accuracy: 0.8822
# 26/26 [==============================] - 9s 361ms/step - loss: 0.3829 - accuracy: 0.8716
# Validation: accuracy = 0.871571  ;  loss_v = 0.382862
# Test: accuracy = 0.882177  ;  loss = 0.330057

# %% [markdown]
# **Function to Plot Confusion Matrix**

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# Predict the values from the validation dataset
Y_pred = model.predict(x_test)
# Convert predictions classes to one hot vectors 
Y_pred_classes = np.argmax(Y_pred,axis = 1) 
# Convert validation observations to one hot vectors
Y_true = np.argmax(y_test,axis = 1) 
# compute the confusion matrix
confusion_mtx = confusion_matrix(Y_true, Y_pred_classes)

 

# plot the confusion matrix
plot_confusion_matrix(confusion_mtx, classes = range(2))

# %% [markdown]
# **Fraction Classified Incorrectly**

# %%
label_frac_error = 1 - np.diag(confusion_mtx) / np.sum(confusion_mtx, axis=1)
plt.bar(np.arange(2),label_frac_error)
plt.xlabel('True Label')
plt.ylabel('Fraction classified incorrectly')
# Out:
# Text(0, 0.5, 'Fraction classified incorrectly')

# %% [markdown]
# **Classification Report**

# %%
labels = ['Benign', 'Malignant']

# validation dataset
Y_pred = model.predict(x_test)

# predictions classes to one hot vectors 
Y_pred_classes = np.argmax(Y_pred,axis = 1) 

# validation observations to one hot vectors
Y_true = np.argmax(y_test,axis = 1) 

print(classification_report(Y_true, Y_pred_classes, target_names=labels))
# Out:
#               precision    recall  f1-score   support
#
#       Benign       0.89      0.98      0.93      1663
#    Malignant       0.80      0.41      0.54       340
#
#     accuracy                           0.88      2003
#    macro avg       0.85      0.69      0.74      2003
# weighted avg       0.87      0.88      0.87      2003
